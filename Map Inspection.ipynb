# %%
import geopandas as gpd

# %%
gpd.read_file('data/Geo/Districts/crs_districts/crs_districts.shp')
# Out:
#     OBJECTID DIST_LABEL DIST_NUM         PDF DISTRICT  \
# 0       1302        9TH        9        None      009
# 1       1303       10TH       10  dist10.pdf      010
# 2       1304        2ND        2        None      002
# 3       1305        8TH        8   dist8.pdf      008
# 4       1282        3RD        3   dist3.pdf      003
# 5       1281        7TH        7   dist7.pdf      007
# 6       1283        4TH        4   dist4.pdf      004
# 7       1284        6TH        6   dist6.pdf      006
# 8       1285       31ST       31        None      031
# 9       1286       22ND       22  dist22.pdf      022
# 10      1287        5TH        5   dist5.pdf      005
# 11      1288       24TH       24  dist24.pdf      024
# 12      1289       16TH       16  dist16.pdf      016
# 13      1290       17TH       17  dist17.pdf      017
# 14      1291       20TH       20  dist20.pdf      020
# 15      1292       31ST       31        None      031
# ...

# %%
gpd.read_file('data/Geo/Districts/cpd_districts.shp')
# Out:
#     OBJECTID DIST_LABEL DIST_NUM         PDF DISTRICT  \
# 0       1302        9TH        9        None      009
# 1       1303       10TH       10  dist10.pdf      010
# 2       1304        2ND        2        None      002
# 3       1305        8TH        8   dist8.pdf      008
# 4       1282        3RD        3   dist3.pdf      003
# 5       1281        7TH        7   dist7.pdf      007
# 6       1283        4TH        4   dist4.pdf      004
# 7       1284        6TH        6   dist6.pdf      006
# 8       1285       31ST       31        None      031
# 9       1286       22ND       22  dist22.pdf      022
# 10      1287        5TH        5   dist5.pdf      005
# 11      1288       24TH       24  dist24.pdf      024
# 12      1289       16TH       16  dist16.pdf      016
# 13      1290       17TH       17  dist17.pdf      017
# 14      1291       20TH       20  dist20.pdf      020
# 15      1292       31ST       31        None      031
# ...
